# %%
import cv2
import pytesseract
import pandas as pd
from pathlib import Path

# ============== TESSERACT SETUP ==============
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

processed_dir = Path("../data/processed")
df = pd.read_csv("../data/annotated/ground_truth.csv")
results = []

print("Running Tesseract OCR (PSM 6 + OEM 1)...\n")

for _, row in df.iterrows():
    img_path = processed_dir / row['filename']
    img = cv2.imread(str(img_path))
    
    if img is None:
        print(f"❌ Could not read {row['filename']}")
        results.append({
            "filename": row["filename"],
            "condition": row["condition"],
            "extracted_text": "",
            "avg_confidence": 0.0
        })
        continue

    # Extract text
    config = "--oem 1 --psm 6"
    extracted_text = pytesseract.image_to_string(img, config=config).strip()
    
    # Get confidence score using image_to_data
    data = pytesseract.image_to_data(img, config=config, output_type=pytesseract.Output.DATAFRAME)
    valid_data = data[data['conf'] > 0]
    avg_conf = valid_data['conf'].mean() / 100.0 if not valid_data.empty else 0.0
    
    # Count non-empty lines
    line_count = len([line for line in extracted_text.split('\n') if line.strip()])
    
    results.append({
        "filename": row["filename"],
        "condition": row["condition"],
        "extracted_text": extracted_text,
        "avg_confidence": round(avg_conf, 4)
    })
    
    print(f"✅ {row['filename']:18} | Conf: {avg_conf:.3f} | Lines: {line_count}")

# Save with the same filename so notebooks 04 & 05 work without changes
ocr_df = pd.DataFrame(results)
ocr_df.to_csv("../outputs/metrics/easyocr_results.csv", index=False)

print("\n" + "="*70)
print("✅ Tesseract OCR completed!")
print(ocr_df[['filename', 'avg_confidence']].to_string(index=False))
# Out:
# Running Tesseract OCR (PSM 6 + OEM 1)...
#
# ✅ receipt_01.jpg     | Conf: 0.762 | Lines: 48
# ✅ receipt_02.jpg     | Conf: 0.685 | Lines: 59
# ✅ receipt_03.jpg     | Conf: 0.721 | Lines: 49
# ✅ receipt_04.jpg     | Conf: 0.573 | Lines: 48
# ✅ receipt_05.jpg     | Conf: 0.719 | Lines: 20
# ✅ receipt_06.jpg     | Conf: 0.643 | Lines: 68
# ✅ receipt_07.jpg     | Conf: 0.729 | Lines: 46
# ✅ receipt_08.jpg     | Conf: 0.724 | Lines: 47
# ✅ receipt_09.jpg     | Conf: 0.586 | Lines: 49
# ✅ receipt_10.jpg     | Conf: 0.575 | Lines: 53
# ✅ receipt_11.jpg     | Conf: 0.551 | Lines: 69
# ✅ receipt_12.jpg     | Conf: 0.552 | Lines: 49
# ✅ receipt_13.jpg     | Conf: 0.471 | Lines: 52
# ✅ receipt_14.jpg     | Conf: 0.535 | Lines: 46
# ✅ receipt_15.jpg     | Conf: 0.520 | Lines: 40
# ✅ receipt_16.jpg     | Conf: 0.523 | Lines: 30
# ✅ receipt_17.jpg     | Conf: 0.534 | Lines: 61
#
# ======================================================================
# ✅ Tesseract OCR completed!
#       filename  avg_confidence
# receipt_01.jpg          0.7624
# receipt_02.jpg          0.6855
# receipt_03.jpg          0.7208
# receipt_04.jpg          0.5734
# receipt_05.jpg          0.7185
# receipt_06.jpg          0.6431
# receipt_07.jpg          0.7290
# receipt_08.jpg          0.7236
# receipt_09.jpg          0.5857
# receipt_10.jpg          0.5748
# receipt_11.jpg          0.5515
# receipt_12.jpg          0.5520
# receipt_13.jpg          0.4714
# receipt_14.jpg          0.5353
# receipt_15.jpg          0.5202
# receipt_16.jpg          0.5230
# receipt_17.jpg          0.5335
